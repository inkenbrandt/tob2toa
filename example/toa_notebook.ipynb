# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../src/')
import tob2toa

# %%
tob2toa.convert_tob3_to_toa5('21314_Flux_CSFormat_52.dat', 'toa_example_long.csv')
# Out:
#   Table: Flux_CSFormat
#   Frame size: 416, Record size: 400
#   Records/frame: 1
#   Total frames: 970
#   Validation stamp: 48781
#   Valid records: 656
#   Output: toa_example_long.csv
# 'toa_example_long.csv'

# %%
df = tob2toa.tob3_to_dataframe('21314_Time_Series_971.dat')
