# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../src/')
import tob2toa

# %%
tob2toa.convert_tob3_to_toa5('21314_Time_Series_971.dat', 'toa_example_long.csv')
# Out:
#   Table: Time_Series
#   Frame size: 72, Record size: 56
#   Records/frame: 1
#   Total frames: 950429
#   Validation stamp: 16854
#   Valid records: 864000
#   Output: toa_example_long.csv
# 'toa_example_long.csv'

# %%
df = tob2toa.tob3_to_dataframe('21314_Time_Series_971.dat')

# %%
df['Ux'].plot()
# Out:
# <Axes: >
