# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../src/')
import tob2toa

# %%
tob2toa.convert_tob3_to_toa5('21314_Time_Series_971.dat', 'toa_example_long.csv')
# Out:
#   Table: Time_Series
#   Frame size: 72, Record size: 56
#   Records/frame: 1
#   Total frames: 950429
#   Validation stamp: 16854
#   Valid records: 864000
#   Output: toa_example_long.csv
# 'toa_example_long.csv'

# %%
df = tob2toa.toa5_to_pandas('toa_example_long.csv')[0]
# Out:
#                      TIMESTAMP    RECORD        Ux        Uy        Uz  \
# 0      2026-02-25 00:00:00.100  73102429 -2.724231 -1.383633 -0.137416
# 1      2026-02-25 00:00:00.200  73102430 -2.760823 -1.248013  0.068198
# 2      2026-02-25 00:00:00.300  73102431 -2.836998 -1.257373  0.188806
# 3      2026-02-25 00:00:00.400  73102432 -2.809960 -1.385630  0.052862
# 4      2026-02-25 00:00:00.500  73102433 -2.710975 -1.323569 -0.080843
# ...                        ...       ...       ...       ...       ...
# 863995 2026-02-25 23:59:59.600  73966424 -4.764139 -1.597526  0.333449
# 863996 2026-02-25 23:59:59.700  73966425 -4.848300 -2.031085  0.269968
# 863997 2026-02-25 23:59:59.800  73966426 -4.648288 -1.694350  0.154012
# 863998 2026-02-25 23:59:59.900  73966427 -4.828992 -1.683931 -0.252289
# 863999                     NaT  73966428 -5.094328 -2.072510  0.003582
#
#           T_SONIC  diag_sonic  CO2_density  CO2_density_fast_tmpr  \
# 0        9.744670           0     674.9655               679.3901
# 1        9.741067           0     674.6420               679.0623
# 2        9.710856           0     675.4161               679.8195
# 3        9.705137           0     674.7302               679.1270
# 4        9.672883           0     674.9507               679.3264
# ...           ...         ...          ...                    ...
# 863995  11.207500           0     674.6962               679.7021
# 863996  11.107890           0     674.6006               679.5381
# 863997  11.072640           0     673.9286               678.8392
# 863998  11.147780           0     674.3709               679.3351
# 863999  11.404330           0     674.6429               679.7790
#
#         H2O_density  diag_irga  T_SONIC_corr  TA_1_1_1        PA  \
# 0          4.825562          0      9.070862  7.690613  84.34952
# 1          4.823694          0      9.066254  7.690613  84.34763
# 2          4.840551          0      9.032074  7.690613  84.34830
# 3          4.828147          0      9.033569  7.690613  84.34756
# 4          4.837406          0      9.004669  7.690613  84.34753
# ...             ...        ...           ...       ...       ...
# 863995     5.276423          0     10.465240  9.214233  84.69347
# 863996     5.280968          0     10.369780  9.221191  84.69608
# 863997     5.269019          0     10.342770  9.221191  84.69521
# 863998     5.261093          0     10.411990  9.221191  84.69444
# 863999     5.256341          0     10.668270  9.221191  84.69357
#
#         CO2_sig_strgth  H2O_sig_strgth
# 0             0.944685        0.926845
# 1             0.944665        0.926825
# 2             0.944710        0.926845
# 3             0.944693        0.926849
# 4             0.944714        0.926854
# ...                ...             ...
# 863995        0.944782        0.926987
# 863996        0.944689        0.926818
# 863997        0.944686        0.926690
# 863998        0.944928        0.926886
# 863999        0.944856        0.926914
#
# [864000 rows x 16 columns]
